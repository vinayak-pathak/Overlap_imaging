# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayak-pathak/Overlap_imaging/blob/main/final_copy_without_bright_aug_of_9_27_different_seeds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow import keras
from scipy.io import loadmat
import os
from os import path
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %%
#!unzip rawdata-20200330T180426Z-001.zip
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# initializer = keras.initializers.HeNormal()

# def make_cnn_model(image_size=(201, 201, 3), classes=2, summarize=True):
#     input_layer = keras.layers.Input(shape=image_size)
#     # block 0: conv-> strided_conv # change relu to LeakyRelu
#     x = keras.layers.Conv2D(16, 3, padding='same', activation='relu',kernel_initializer=initializer)(input_layer)
#     x = keras.layers.Conv2D(16, 3, strides=2, padding='same', activation='relu',kernel_initializer = initializer)(x)
#     # block 1: conv-> strided_conv
#     x = keras.layers.Conv2D(32, 3, padding='same', activation='relu',kernel_initializer=initializer)(x)
#     x = keras.layers.Conv2D(32, 3, strides=2, padding='same', activation='relu',kernel_initializer=initializer)(x)
#     # block 2: conv-> strided_conv
#     x = keras.layers.Conv2D(64, 3, padding='same', activation='relu',kernel_initializer=initializer)(x)
#     x = keras.layers.Conv2D(64, 3, strides=2, padding='same', activation='relu',kernel_initializer=initializer)(x)
#     # block 3: conv-> strided_conv
#     x = keras.layers.Conv2D(128, 3, padding='same', activation='relu',kernel_initializer=initializer)(x)
#     x = keras.layers.Conv2D(128, 3, strides=2, padding='same', activation='relu',kernel_initializer=initializer)(x)
#     # block 4: flatten -> FC -> layer_norm -> FC -> out
#     x = keras.layers.Flatten()(x)
#     x = keras.layers.Dense(256, activation='relu',kernel_initializer=initializer)(x)

#     #x = keras.layers.BatchNormalization()(x)

#     output = keras.layers.Dense(classes, activation='softmax')(x)
#     model = keras.Model(inputs=input_layer, outputs=output)
#     if summarize:
#         model.summary()
#     return model

# %%
# before we don't have seeds = totally random in each run, now we add seeds for different learning


def make_cnn_model(initializer, image_size=(201, 201, 3), classes=2, summarize=True):
    input_layer = keras.layers.Input(shape=image_size)
    # block 0: conv-> strided_conv # change relu to LeakyRelu
    x = keras.layers.Conv2D(16, 3, padding='same', activation=keras.layers.LeakyReLU(alpha=0.001),kernel_initializer=initializer)(input_layer)
    x = keras.layers.Conv2D(16, 3, strides=2, padding='same', activation=keras.layers.LeakyReLU(alpha=0.001),kernel_initializer = initializer)(x)
    # block 1: conv-> strided_conv
    x = keras.layers.Conv2D(32, 3, padding='same', activation=keras.layers.LeakyReLU(alpha=0.001),kernel_initializer=initializer)(x)
    x = keras.layers.Conv2D(32, 3, strides=2, padding='same', activation=keras.layers.LeakyReLU(alpha=0.001),kernel_initializer=initializer)(x)
    # block 2: conv-> strided_conv
    x = keras.layers.Conv2D(64, 3, padding='same', activation=keras.layers.LeakyReLU(alpha=0.001),kernel_initializer=initializer)(x)
    x = keras.layers.Conv2D(64, 3, strides=2, padding='same', activation=keras.layers.LeakyReLU(alpha=0.001),kernel_initializer=initializer)(x)
    # block 3: conv-> strided_conv
    x = keras.layers.Conv2D(128, 3, padding='same', activation=keras.layers.LeakyReLU(alpha=0.001),kernel_initializer=initializer)(x)
    x = keras.layers.Conv2D(128, 3, strides=2, padding='same', activation=keras.layers.LeakyReLU(alpha=0.001),kernel_initializer=initializer)(x)
    # block 4: flatten -> FC -> layer_norm -> FC -> out
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(256, activation=keras.layers.LeakyReLU(alpha=0.001),kernel_initializer=initializer)(x)

    #x = keras.layers.BatchNormalization()(x)

    output = keras.layers.Dense(classes, activation='softmax')(x)
    model = keras.Model(inputs=input_layer, outputs=output)
    if summarize:
        model.summary()
    return model

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-ad2fd893293f> in <module>()
# ----> 1 model = make_cnn_model()
#
# TypeError: make_cnn_model() missing 1 required positional argument: 'initializer'

# %%
import time
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
 
datagen = ImageDataGenerator(
    # add a color aug?
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    #brightness_range=(0.2, 2),
    horizontal_flip=True,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest'
    )

# %%
def imdisp(im_seq_1):
  plt.figure(figsize=(15, 6)) # the first arg contral the horizontal distance
  for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(im_seq_1[i]) # 显示图片
    plt.axis('on') # 不显示坐标轴
    #plt.title('WBC')
  # for i in range(5):
  #   plt.subplot(2,5,i+6)|
  #   plt.imshow(im_seq_2[i+5]) # 显示图片
  #   plt.axis('on') # 不显示坐标轴
  #   #plt.title('RBC')
  plt.show()

# %%
from PIL import Image
from numpy import *
from scipy.ndimage import filters
def load_dataset(split=0.7, sum_channels=False, augment = False):
    ###################### generate train & validation ######################
    path = "/content/gdrive/My Drive/overlap/NPY_1"
    positive_images = np.load(os.path.join(path, 'WBC.npy')).astype(np.float32)
    negative_images = np.load(os.path.join(path, 'RBC.npy')).astype(np.float32)

    print('original negative_images.shape = ')
    print(negative_images.shape)
    print('original positive_images.shape = ')
    print(positive_images.shape)
    print("Display Original Images:")
    imdisp(positive_images.astype(uint8))

    if sum_channels:
        # sum the last channel, keepdims keyword argument prevents collapsing the channel axis
        negative_images = np.sum(negative_images, axis=-1, keepdims=True)
        positive_images = np.sum(positive_images, axis=-1, keepdims=True)
        
    if augment:
      n_label = np.zeros(negative_images.shape[0])
      p_label = np.ones(positive_images.shape[0])
      f_neg=datagen.flow(negative_images,n_label,batch_size=negative_images.shape[0])
      f_pos=datagen.flow(positive_images,p_label,batch_size=positive_images.shape[0])
      aug_i=0
      while True:
          if aug_i==9:
              break
          time.sleep(1)
          aug_i +=1
          x_neg,y_neg=next(f_neg)
          x_pos,y_pos=next(f_pos)
          negative_images = np.insert(negative_images, 0, values=x_neg, axis=0)
          positive_images = np.insert(positive_images, 0, values=x_pos, axis=0)

    print('augemented negative_images.shape = ')
    print(negative_images.shape)
    print('augemented positive_images.shape = ')
    print(positive_images.shape)
    print("Display augmented Images:")
    imdisp(positive_images.astype(uint8))
   
    #shuffling along first axis
    np.random.seed(0) # shall we try other seeds
    np.random.shuffle(negative_images)
    np.random.shuffle(positive_images)
        
    train_negative_amnt = int(negative_images.shape[0]*split)
    negative_train_images = negative_images[:train_negative_amnt]
    negative_val_images = negative_images[train_negative_amnt:]

    train_positive_amnt = int(positive_images.shape[0]*split)
    positive_train_images = positive_images[:train_positive_amnt]
    positive_val_images = positive_images[train_positive_amnt:]

    print('negative_train_images number = ')
    print(negative_train_images.shape[0])
    print('negative_val_images number = ')
    print(negative_val_images.shape[0])

    return (negative_train_images, positive_train_images), (negative_val_images, positive_val_images)

# %%
(negative_train_images, positive_train_images), (negative_val_images, positive_val_images)= load_dataset(augment = False)
# Out:
# original negative_images.shape =
# (420, 201, 201, 3)
# original positive_images.shape =
# (449, 201, 201, 3)
# Display Original Images:
# augemented negative_images.shape =
# (420, 201, 201, 3)
# augemented positive_images.shape =
# (449, 201, 201, 3)
# Display augmented Images:
# negative_train_images number =
# 294
# negative_val_images number =
# 126

# %%
# test different normalization methods

# %%
def shot_noise(input_image, n):
  # x_axis = input_image.shape[0]
  # y_axis = input_image.shape[1]
  input_image = input_image+n*np.random.normal(loc=0.0, scale=np.sqrt(1/n*np.abs(input_image)*(1-1/n)*255/20000), size=[input_image.shape[0],input_image.shape[1],input_image.shape[2],input_image.shape[3],input_image.shape[4]])
  return input_image

def norm_after_aug(overlapped_images):
  overlapped_images = np.clip(overlapped_images.astype(np.float32), 0.0, 255)
  overlapped_images = overlapped_images.astype(np.float32)/255 - 0.5 
  return overlapped_images

# %%
class OverlapGenerator(keras.utils.Sequence):
    def __init__(self, positive_images, negative_images, overlap_number=2, batch_size=32, normalize=False, add_noise=True, aug = True):
        assert (batch_size // 2)*2 == batch_size
        self.overlap_number = overlap_number
        self.positive_images = positive_images
        self.negative_images = negative_images
        #print(self.negative_images.shape)
        self.batch_size = batch_size
        self.normalize = normalize
        self.add_noise = add_noise
        # number of positive samples (*2 for total samples)
        self.num_batches = int(min(len(self.positive_images), len(self.negative_images))*2 // self.batch_size)
        self.samples = self.num_batches*self.batch_size//2
        self.labels = None
        self.overlapped_images = None
        self.on_epoch_end()
        self.aug = aug

    def on_epoch_end(self):
        positive_indices = np.arange(0, len(self.positive_images))
        negative_indices = np.arange(0, len(self.negative_images))
        # replace = False is critical
        positive_samples = np.random.choice(positive_indices, size=self.samples, replace=False) #positive - infected
        overlapped_images = []
        # if normalization:
        
        for i in range(self.samples): # generate digital overlapped infected images
            negative_overlap_indices = np.random.choice(negative_indices, size=self.overlap_number-1, replace=False)# select N-1 noninfected sample
            stack = np.concatenate([self.positive_images[positive_samples[i]:positive_samples[i]+1],self.negative_images[negative_overlap_indices]], axis=0)# concatenate 1 infected with N-1 noninfected
            overlapped_image = np.sum(stack, axis=0)
            overlapped_images.append(overlapped_image)

        for i in range(self.samples): # generate digital overlapped noninfected images:
            negative_overlap_indices = np.random.choice(negative_indices, size=self.overlap_number, replace=False)
            overlapped_image = np.sum(self.negative_images[negative_overlap_indices], axis=0)# the shape of overlapped image is 28*28*1
            overlapped_images.append(overlapped_image)

        overlapped_images = np.array(overlapped_images)
        print("The shape after overlap:")
        print(overlapped_images.shape)
        # img_dis = overlapped_images
        # img_dis = img_dis // self.overlap_number
        # imdisp(img_dis.astype(np.uint8))

        # 0 - noninfected, 1 - infected
        labels = np.zeros(self.samples*2)
        labels[0:self.samples] = 1
        # transfer the label to one-hot
        labels = keras.utils.to_categorical(labels)
        sample_indices = np.arange(0, len(overlapped_images))
        # ramdom shuffle
        np.random.shuffle(sample_indices)
        overlapped_images = overlapped_images[sample_indices]
        labels = labels[sample_indices]

        print("Before reshape The shape = ")
        print(overlapped_images.shape)
        # now re-shape to have batch_size samples in each
        # before reshape: (MxN, 201,201,3); after reshape: (M, N = 8, 201, 201, 3)
        overlapped_images = np.reshape(overlapped_images, (self.num_batches, -1, overlapped_images.shape[1],overlapped_images.shape[2],overlapped_images.shape[3] ))
        print("After reshape The shape = ")
        print(overlapped_images.shape)
        labels = np.reshape(labels, (self.num_batches, -1, 2))

        # add noise
        if self.add_noise:
            #overlapped_images = overlapped_images + 0.05*np.abs(np.random.normal(loc=0.0, scale=np.sqrt(np.mean(overlapped_images.flatten())), size=overlapped_images.shape))
            #overlapped_images = overlapped_images + 0.05*np.abs(np.random.normal(loc=0.0, scale=np.sqrt(np.abs(np.mean(overlapped_images.flatten()))), size=overlapped_images.shape))
            #print(overlapped_images.shape)
            overlapped_images = shot_noise(overlapped_images, self.overlap_number)
            overlapped_images = np.clip(overlapped_images, 0.0, 255*self.overlap_number)
            overlapped_images = (overlapped_images) / (255*self.overlap_number) # why 512 = 256*2 = 2^9
            #overlapped_images = np.clip(overlapped_images, 0.0, 1.0)
            # overlapped_images = np.int0(255*overlapped_images).astype(np.float32)/255 - 0.5 
            # figure()
            # imshow(overlapped_images.astype(np.uint8),vmin = 0, vmax = 255)

            overlapped_images = (255*overlapped_images).astype(np.uint8)
            # Q: after add the noise the pixel value may larger than 1 -> any effection?
        #show_in_sequence(overlapped_images[0,:,:,:,:], rgb = False)

        if self.normalize: # nolonger use this, use norma_aft_aug
            # print("show the pretrained overlapped image")
            # imdisp(overlapped_images[0,:,:,:])
            overlapped_images = np.clip(overlapped_images.astype(np.float32), 0.0, 255)
            overlapped_images = overlapped_images.astype(np.float32)/255 - 0.5 
            # Q: do this to each channel, will it change the original image property?
        self.labels = labels
        self.overlapped_images = overlapped_images

    def __len__(self):
        return self.num_batches

    # def __getitem__(self, index):
    def __getitem__(self, index):
      if self.aug: #if you want to see the augmented data, use generated_train.overlapped_images
        return next(datagen.flow(self.overlapped_images[index],shuffle=False)), self.labels[index]
      else:
        return self.overlapped_images[index].astype(np.uint8), self.labels[index]

# %%
# for k in range(10):
#   generator_val = OverlapGenerator(positive_images=positive_val_images, negative_images=negative_val_images, overlap_number=k+1,batch_size=8, aug = False)

# %%
####### Run to see the size #######
overlaps = np.arange(1, 2, 1)
train_accs = np.zeros_like(overlaps, dtype=np.float)
train_losses = np.zeros_like(overlaps, dtype=np.float)
test_accs = np.zeros_like(overlaps, dtype=np.float)
test_losses = np.zeros_like(overlaps, dtype=np.float)
val_accs = np.zeros_like(overlaps, dtype=np.float)
val_losses = np.zeros_like(overlaps, dtype=np.float)
for i, overlap in tqdm(enumerate(overlaps), total=len(overlaps)):
    print("N = "+str(overlaps[i]))
    generator_train = OverlapGenerator(positive_images=positive_train_images, negative_images=negative_train_images, overlap_number=overlap,batch_size=8,normalize=False,aug=True)
    for k in range(10):
        imdisp(generator_train.overlapped_images[k])
    # if self.normalize:
    #         overlapped_images = (overlapped_images) / (255*self.overlap_number) # why 512 = 256*2 = 2^9
    #         #overlapped_images = np.clip(overlapped_images, 0.0, 1.0)
    #         # overlapped_images = np.int0(255*overlapped_images).astype(np.float32)/255 - 0.5 
    #         # figure()
    #         # imshow(overlapped_images.astype(np.uint8),vmin = 0, vmax = 255)

    #         overlapped_images = (255*overlapped_images).astype(np.uint8)
    #         # print("show the pretrained overlapped image")
    #         # imdisp(overlapped_images[0,:,:,:])
    #         overlapped_images = overlapped_images.astype(np.float32)/255 - 0.5 
    #         # Q: do this to each channel, will it change the original image property?


    #generator_val = OverlapGenerator(positive_images=positive_val_images, negative_images=negative_val_images, overlap_number=overlap,batch_size=8,aug = False)
    # imdisp(generator_train.overlapped_images[0])
    # ####### model2 for validation #######
    # generator_val = OverlapGenerator(positive_images=positive_val_images, negative_images=negative_val_images, overlap_number=overlap,batch_size=8, aug = False)
    # model2 = make_cnn_model(summarize=False)
    # model2.compile(adam, loss='categorical_crossentropy',metrics=['accuracy'])
    # model2.fit(x=generator_train, validation_data=generator_val, epochs=50, verbose=1)
    # history2 = model2.history.history
    # val_accs[i] = np.mean(history2['val_accuracy'])
    # val_losses[i] = np.mean(history2['val_loss'])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# N = 1
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)

# %%
seednum = 2
initializer = keras.initializers.HeNormal(seed=seednum)
#model = make_cnn_model(initializer)

# %%
################# run a single overlap number #####################
from tensorflow.keras.callbacks import ModelCheckpoint
overlaps = 5
train_accs = np.zeros_like(overlaps, dtype=np.float)
train_losses = np.zeros_like(overlaps, dtype=np.float)
val_accs = np.zeros_like(overlaps, dtype=np.float)
val_losses = np.zeros_like(overlaps, dtype=np.float)
test_accs = np.zeros_like(overlaps, dtype=np.float)
test_losses = np.zeros_like(overlaps, dtype=np.float)

# dynamic augmentation
generator_train = OverlapGenerator(positive_images=positive_train_images, negative_images=negative_train_images, overlap_number=overlaps,batch_size=8)
#print(next(generator_train).astype(np.uint8).shape)
#print(generator_train.overlapped_images.shape)
generator_val = OverlapGenerator(positive_images=positive_val_images, negative_images=negative_val_images, overlap_number=overlaps,batch_size=8, aug = False)
#generator_test = OverlapGenerator(positive_images=positive_test_images, negative_images=negative_test_images, overlap_number=overlaps,batch_size=8,aug = False)
imdisp(generator_train.overlapped_images[0])
imdisp(generator_val.overlapped_images[0])

#generator_train.overlapped_images = norm_after_aug(generator_train.overlapped_images).astype(np.float32)
#generator_val.overlapped_images = norm_after_aug(generator_val.overlapped_images).astype(np.float32)

generator_train.overlapped_images = norm_after_aug(generator_train.overlapped_images)
generator_val.overlapped_images = norm_after_aug(generator_val.overlapped_images)

model = make_cnn_model(initializer, summarize=False)
# model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=['accuracy'])
adam = keras.optimizers.Adamax(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)#0.001 -> 0.0005
model.compile(adam, loss='categorical_crossentropy',metrics=['accuracy'])  

filepath=f"/content/gdrive/My Drive/overlap/weights/weights_final/9_27_test_n{overlaps}_nobrightaug_uint8_Lrelu_weights_seed{seednum}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True,mode='max')
callbacks_list = [checkpoint]

history = model.fit(x=generator_train, validation_data=generator_val, epochs=60,callbacks=callbacks_list)
#model.save('my_model3.h5')   # HDF5 file, you have to pip3 install h5py if don't have it
# Out:
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7205 - accuracy: 0.5702The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 8s 98ms/step - loss: 0.7205 - accuracy: 0.5702 - val_loss: 0.6931 - val_accuracy: 0.5000
#
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to /content/gdrive/My Drive/overlap/weights/weights_final/9_27_test_n5_nobrightaug_uint8_Lrelu_weights_seed2.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 2/60
# 73/73 [==============================] - ETA: 0s - loss: 2.8745 - accuracy: 0.5257The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 98ms/step - loss: 2.8745 - accuracy: 0.5257 - val_loss: 0.6740 - val_accuracy: 0.7056
#
# Epoch 00002: val_accuracy improved from 0.50000 to 0.70565, saving model to /content/gdrive/My Drive/overlap/weights/weights_final/9_27_test_n5_nobrightaug_uint8_Lrelu_weights_seed2.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 3/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6851 - accuracy: 0.5702The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 98ms/step - loss: 0.6851 - accuracy: 0.5702 - val_loss: 0.6282 - val_accuracy: 0.8065
#
# Epoch 00003: val_accuracy improved from 0.70565 to 0.80645, saving model to /content/gdrive/My Drive/overlap/weights/weights_final/9_27_test_n5_nobrightaug_uint8_Lrelu_weights_seed2.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 4/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7081 - accuracy: 0.6010The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.7081 - accuracy: 0.6010 - val_loss: 0.6639 - val_accuracy: 0.5000
#
# Epoch 00004: val_accuracy did not improve from 0.80645
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 5/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6642 - accuracy: 0.6627The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.6642 - accuracy: 0.6627 - val_loss: 0.3537 - val_accuracy: 0.8589
#
# Epoch 00005: val_accuracy improved from 0.80645 to 0.85887, saving model to /content/gdrive/My Drive/overlap/weights/weights_final/9_27_test_n5_nobrightaug_uint8_Lrelu_weights_seed2.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 6/60
# 73/73 [==============================] - ETA: 0s - loss: 0.4381 - accuracy: 0.7894The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 98ms/step - loss: 0.4381 - accuracy: 0.7894 - val_loss: 0.3631 - val_accuracy: 0.8468
#
# Epoch 00006: val_accuracy did not improve from 0.85887
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 7/60
# 73/73 [==============================] - ETA: 0s - loss: 0.4333 - accuracy: 0.8048The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.4333 - accuracy: 0.8048 - val_loss: 0.2723 - val_accuracy: 0.8911
#
# Epoch 00007: val_accuracy improved from 0.85887 to 0.89113, saving model to /content/gdrive/My Drive/overlap/weights/weights_final/9_27_test_n5_nobrightaug_uint8_Lrelu_weights_seed2.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 8/60
# 73/73 [==============================] - ETA: 0s - loss: 0.4934 - accuracy: 0.7825The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.4934 - accuracy: 0.7825 - val_loss: 0.2558 - val_accuracy: 0.8992
#
# Epoch 00008: val_accuracy improved from 0.89113 to 0.89919, saving model to /content/gdrive/My Drive/overlap/weights/weights_final/9_27_test_n5_nobrightaug_uint8_Lrelu_weights_seed2.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 9/60
# 73/73 [==============================] - ETA: 0s - loss: 0.4518 - accuracy: 0.7962The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 99ms/step - loss: 0.4518 - accuracy: 0.7962 - val_loss: 0.2879 - val_accuracy: 0.8871
#
# Epoch 00009: val_accuracy did not improve from 0.89919
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 10/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3821 - accuracy: 0.8236The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.3821 - accuracy: 0.8236 - val_loss: 0.2786 - val_accuracy: 0.8911
#
# Epoch 00010: val_accuracy did not improve from 0.89919
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 11/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8271The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 96ms/step - loss: 0.3759 - accuracy: 0.8271 - val_loss: 0.2789 - val_accuracy: 0.8992
#
# Epoch 00011: val_accuracy did not improve from 0.89919
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 12/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3727 - accuracy: 0.8442The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.3727 - accuracy: 0.8442 - val_loss: 0.2841 - val_accuracy: 0.8750
#
# Epoch 00012: val_accuracy did not improve from 0.89919
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 13/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3632 - accuracy: 0.8236The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 96ms/step - loss: 0.3632 - accuracy: 0.8236 - val_loss: 0.2546 - val_accuracy: 0.8992
#
# Epoch 00013: val_accuracy did not improve from 0.89919
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 14/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3280 - accuracy: 0.8613The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 98ms/step - loss: 0.3280 - accuracy: 0.8613 - val_loss: 0.1886 - val_accuracy: 0.9274
#
# Epoch 00014: val_accuracy improved from 0.89919 to 0.92742, saving model to /content/gdrive/My Drive/overlap/weights/weights_final/9_27_test_n5_nobrightaug_uint8_Lrelu_weights_seed2.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 15/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3679 - accuracy: 0.8476The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 99ms/step - loss: 0.3679 - accuracy: 0.8476 - val_loss: 0.2228 - val_accuracy: 0.9113
#
# Epoch 00015: val_accuracy did not improve from 0.92742
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 16/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3470 - accuracy: 0.8373The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 96ms/step - loss: 0.3470 - accuracy: 0.8373 - val_loss: 0.1685 - val_accuracy: 0.9476
#
# Epoch 00016: val_accuracy improved from 0.92742 to 0.94758, saving model to /content/gdrive/My Drive/overlap/weights/weights_final/9_27_test_n5_nobrightaug_uint8_Lrelu_weights_seed2.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 17/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3156 - accuracy: 0.8750The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.3156 - accuracy: 0.8750 - val_loss: 0.1543 - val_accuracy: 0.9435
#
# Epoch 00017: val_accuracy did not improve from 0.94758
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 18/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.8630The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.3451 - accuracy: 0.8630 - val_loss: 0.1778 - val_accuracy: 0.9315
#
# Epoch 00018: val_accuracy did not improve from 0.94758
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 19/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3033 - accuracy: 0.8784The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.3033 - accuracy: 0.8784 - val_loss: 0.2100 - val_accuracy: 0.9073
#
# Epoch 00019: val_accuracy did not improve from 0.94758
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 20/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3544 - accuracy: 0.8562The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.3544 - accuracy: 0.8562 - val_loss: 0.1423 - val_accuracy: 0.9556
#
# Epoch 00020: val_accuracy improved from 0.94758 to 0.95565, saving model to /content/gdrive/My Drive/overlap/weights/weights_final/9_27_test_n5_nobrightaug_uint8_Lrelu_weights_seed2.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 21/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3536 - accuracy: 0.8425The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 98ms/step - loss: 0.3536 - accuracy: 0.8425 - val_loss: 0.2051 - val_accuracy: 0.8911
#
# Epoch 00021: val_accuracy did not improve from 0.95565
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 22/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3777 - accuracy: 0.8322The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 98ms/step - loss: 0.3777 - accuracy: 0.8322 - val_loss: 0.1472 - val_accuracy: 0.9435
#
# Epoch 00022: val_accuracy did not improve from 0.95565
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 23/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3434 - accuracy: 0.8527The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.3434 - accuracy: 0.8527 - val_loss: 0.2199 - val_accuracy: 0.9073
#
# Epoch 00023: val_accuracy did not improve from 0.95565
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 24/60
# 73/73 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9127The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.2372 - accuracy: 0.9127 - val_loss: 0.1128 - val_accuracy: 0.9516
#
# Epoch 00024: val_accuracy did not improve from 0.95565
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 25/60
# 73/73 [==============================] - ETA: 0s - loss: 0.4087 - accuracy: 0.8579The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 96ms/step - loss: 0.4087 - accuracy: 0.8579 - val_loss: 0.3008 - val_accuracy: 0.8871
#
# Epoch 00025: val_accuracy did not improve from 0.95565
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 26/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3892 - accuracy: 0.8373The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.3892 - accuracy: 0.8373 - val_loss: 0.1038 - val_accuracy: 0.9597
#
# Epoch 00026: val_accuracy improved from 0.95565 to 0.95968, saving model to /content/gdrive/My Drive/overlap/weights/weights_final/9_27_test_n5_nobrightaug_uint8_Lrelu_weights_seed2.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 27/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.8750The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 99ms/step - loss: 0.3099 - accuracy: 0.8750 - val_loss: 0.1419 - val_accuracy: 0.9476
#
# Epoch 00027: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 28/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3399 - accuracy: 0.8545The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 98ms/step - loss: 0.3399 - accuracy: 0.8545 - val_loss: 0.1944 - val_accuracy: 0.9597
#
# Epoch 00028: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 41/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3123 - accuracy: 0.8870The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 98ms/step - loss: 0.3123 - accuracy: 0.8870 - val_loss: 0.1491 - val_accuracy: 0.9556
#
# Epoch 00041: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 42/60
# 73/73 [==============================] - ETA: 0s - loss: 0.2640 - accuracy: 0.8836The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.2640 - accuracy: 0.8836 - val_loss: 0.1640 - val_accuracy: 0.9153
#
# Epoch 00042: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 43/60
# 73/73 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.8613The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.2955 - accuracy: 0.8613 - val_loss: 0.1472 - val_accuracy: 0.9476
#
# Epoch 00043: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 44/60
# 73/73 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.8990The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 7s 97ms/step - loss: 0.2657 - accuracy: 0.8990 - val_loss: 0.1783 - val_accuracy: 0.9395
#
# Epoch 00044: val_accuracy did not improve from 0.95968

# %%
# Plot training & test accuracy values
plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'],marker='o')
plt.plot(history.history['val_accuracy'],marker='o')
#plt.title('Model accuracy')
plt.ylabel('Accuracy',fontsize=16)
plt.xlabel('Epoch',fontsize=16)
plt.legend(['Train', 'Val'], loc='upper left',prop = {'size':14})
plt.title("Train&Val Acc, n = 2")
plt.show()

# Plot training & test loss values
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'][1:],marker='o')
plt.plot(history.history['val_loss'][1:],marker='o')
#plt.title('Model loss')
plt.ylabel('Loss',fontsize=16)
plt.xlabel('Epoch',fontsize=16)
plt.legend(['Train', 'Val'], loc='upper left',prop = {'size':14})
plt.grid()
plt.title("Train&Val Loss, n = 2")
plt.show()

# %%
model.save('/content/gdrive/My Drive/overlap/New setup/9_16_n2_uint8_Lrelu_weights.h5')

# %%
# Plot training & test accuracy values
plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'],marker='o')
plt.plot(history.history['val_accuracy'],marker='o')
#plt.title('Model accuracy')
plt.ylabel('Accuracy',fontsize=16)
plt.xlabel('Epoch',fontsize=16)
plt.legend(['Train', 'Val'], loc='upper left',prop = {'size':14})
plt.title("Train&Val Acc, n = 2")
plt.show()

# Plot training & test loss values
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'],marker='o')
plt.plot(history.history['val_loss'],marker='o')
#plt.title('Model loss')
plt.ylabel('Loss',fontsize=16)
plt.xlabel('Epoch',fontsize=16)
plt.legend(['Train', 'Val'], loc='upper left',prop = {'size':14})
plt.grid()
plt.title("Train&Val Loss, n = 2")
plt.show()

# %%
# Plot training & test accuracy values
plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'],marker='o')
plt.plot(history.history['val_accuracy'],marker='o')
#plt.title('Model accuracy')
plt.ylabel('Accuracy',fontsize=16)
plt.xlabel('Epoch',fontsize=16)
plt.legend(['Train', 'Val'], loc='upper left',prop = {'size':14})
plt.title("Train&Val Acc, n = 7")
plt.show()

# Plot training & test loss values
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'],marker='o')
plt.plot(history.history['val_loss'],marker='o')
#plt.title('Model loss')
plt.ylabel('Loss',fontsize=16)
plt.xlabel('Epoch',fontsize=16)
plt.legend(['Train', 'Val'], loc='upper left',prop = {'size':14})
plt.title("Train&Val Loss, n = 7")
plt.show()

# %%
# plt.figure(figsize=(10,5))
# plt.xticks(overlaps)
# plt.plot(overlaps, train_accs, label='train acc', marker='o')
# plt.plot(overlaps, val_accs, label='val acc', marker='o')
# plt.plot(overlaps, test_accs, label='Test acc', marker='o')
# plt.xlabel("Number of overlaps",fontsize=16)
# plt.ylabel("Accuracy",fontsize=16)
# plt.legend(prop = {'size':14})

# %% [markdown]
# Select the best accuracy parameters for both test and validation

# %%
################# run a single overlap number #####################
from tensorflow.keras.callbacks import ModelCheckpoint
overlaps = 2
train_accs = np.zeros_like(overlaps, dtype=np.float)
train_losses = np.zeros_like(overlaps, dtype=np.float)
val_accs = np.zeros_like(overlaps, dtype=np.float)
val_losses = np.zeros_like(overlaps, dtype=np.float)
test_accs = np.zeros_like(overlaps, dtype=np.float)
test_losses = np.zeros_like(overlaps, dtype=np.float)

# dynamic augmentation
generator_train = OverlapGenerator(positive_images=positive_train_images, negative_images=negative_train_images, overlap_number=overlaps,batch_size=8)
#print(next(generator_train).astype(np.uint8).shape)
#print(generator_train.overlapped_images.shape)
generator_val = OverlapGenerator(positive_images=positive_val_images, negative_images=negative_val_images, overlap_number=overlaps,batch_size=8, aug = False)
#generator_test = OverlapGenerator(positive_images=positive_test_images, negative_images=negative_test_images, overlap_number=overlaps,batch_size=8,aug = False)
imdisp(generator_train.overlapped_images[0])
imdisp(generator_val.overlapped_images[0])


generator_train.overlapped_images = norm_after_aug(generator_train.overlapped_images)
generator_val.overlapped_images = norm_after_aug(generator_val.overlapped_images)

model = make_cnn_model(summarize=False)
# model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=['accuracy'])
adam = keras.optimizers.Adamax(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)#0.001 -> 0.0005
model.compile(adam, loss='categorical_crossentropy',metrics=['accuracy'])  

filepath="9_19_test_n2_brightaug_uint8_Lrelu_weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True,mode='max')
callbacks_list = [checkpoint]

history = model.fit(x=generator_train, validation_data=generator_val, epochs=60,callbacks=callbacks_list)
#model.save('my_model3.h5')   # HDF5 file, you have to pip3 install h5py if don't have it

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
overlaps = np.arange(5, 8, 1)
train_accs = np.zeros_like(overlaps, dtype=np.float)
train_losses = np.zeros_like(overlaps, dtype=np.float)
# test_accs = np.zeros_like(overlaps, dtype=np.float)
# test_losses = np.zeros_like(overlaps, dtype=np.float)
val_accs = np.zeros_like(overlaps, dtype=np.float)
val_losses = np.zeros_like(overlaps, dtype=np.float)

train_accs_ave = np.zeros_like(overlaps, dtype=np.float)
train_losses_ave = np.zeros_like(overlaps, dtype=np.float)
# test_accs = np.zeros_like(overlaps, dtype=np.float)
# test_losses = np.zeros_like(overlaps, dtype=np.float)
val_accs_ave = np.zeros_like(overlaps, dtype=np.float)
val_losses_ave = np.zeros_like(overlaps, dtype=np.float)
for i, overlap in tqdm(enumerate(overlaps), total=len(overlaps)):
    generator_train = OverlapGenerator(positive_images=positive_train_images, negative_images=negative_train_images, overlap_number=overlap,batch_size=8)
    generator_val = OverlapGenerator(positive_images=positive_val_images, negative_images=negative_val_images, overlap_number=overlap,batch_size=8, aug = False)#,aug = False
    
    generator_train.overlapped_images = norm_after_aug(generator_train.overlapped_images)
    generator_val.overlapped_images = norm_after_aug(generator_val.overlapped_images)

    model = make_cnn_model(summarize=False)
    adam = keras.optimizers.Adamax(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)
    model.compile(adam, loss='categorical_crossentropy',metrics=['accuracy']) 

    filepath='/content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n' + str(overlap)+'.hdf5'
    #filepath='n' + str(i+1)+"_weights.best.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True,mode='max')
    callbacks_list = [checkpoint]

    #model.fit(x=generator_train, validation_data=generator_val, epochs=60) # if use callback need to add it
    model.fit(x=generator_train, validation_data=generator_val, epochs=60, callbacks=callbacks_list)

    history = model.history.history
    # train_accs[i] = np.mean(history['accuracy'][20:50])
    # train_losses[i] = np.mean(history['loss'][20:50])
    # val_accs[i] = np.mean(history['val_accuracy'][20:50])
    # val_losses[i] = np.mean(history['val_loss'][20:50])
    
    # the last accuracy
    train_accs[i] = history['accuracy'][59]
    train_losses[i] = history['loss'][59]
    val_accs[i] = history['val_accuracy'][59]
    val_losses[i] = history['val_loss'][59]
    
    # the average acc for last 5
    train_accs_ave[i] = np.mean(history['accuracy'][54:59])
    train_losses_ave[i] = np.mean(history['loss'][54:59])
    val_accs_ave[i] = np.mean(history['val_accuracy'][54:59])
    val_losses_ave[i] = np.mean(history['val_loss'][54:59])

np.save('/content/gdrive/My Drive/overlap/New setup/9_19_tacc567.npy', train_accs)
np.save('/content/gdrive/My Drive/overlap/New setup/9_19_vacc567.npy', val_accs)
np.save('/content/gdrive/My Drive/overlap/New setup/9_19_tacca567.npy', train_accs_ave)
np.save('/content/gdrive/My Drive/overlap/New setup/9_19_vacca567.npy', val_accs_ave)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7292 - accuracy: 0.5342The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 691ms/step - loss: 0.7292 - accuracy: 0.5342 - val_loss: 0.6819 - val_accuracy: 0.5161
#
# Epoch 00001: val_accuracy improved from -inf to 0.51613, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n5.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 2/60
# 73/73 [==============================] - ETA: 0s - loss: 6.1913 - accuracy: 0.5086The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 726ms/step - loss: 6.1913 - accuracy: 0.5086 - val_loss: 0.5739 - val_accuracy: 0.6089
#
# Epoch 00002: val_accuracy improved from 0.51613 to 0.60887, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n5.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 3/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5350 - accuracy: 0.7140The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 688ms/step - loss: 0.5350 - accuracy: 0.7140 - val_loss: 0.6793 - val_accuracy: 0.6129
#
# Epoch 00003: val_accuracy improved from 0.60887 to 0.61290, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n5.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 4/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5346 - accuracy: 0.7363The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 727ms/step - loss: 0.5346 - accuracy: 0.7363 - val_loss: 0.2326 - val_accuracy: 0.9032
#
# Epoch 00004: val_accuracy improved from 0.61290 to 0.90323, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n5.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 5/60
# 73/73 [==============================] - ETA: 0s - loss: 0.4666 - accuracy: 0.7911The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 686ms/step - loss: 0.4666 - accuracy: 0.7911 - val_loss: 0.2223 - val_accuracy: 0.9113
#
# Epoch 00005: val_accuracy improved from 0.90323 to 0.91129, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n5.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 6/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5241 - accuracy: 0.7740The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 690ms/step - loss: 0.5241 - accuracy: 0.7740 - val_loss: 0.3686 - val_accuracy: 0.8145
#
# Epoch 00006: val_accuracy did not improve from 0.91129
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 7/60
# 73/73 [==============================] - ETA: 0s - loss: 0.4695 - accuracy: 0.7911The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 684ms/step - loss: 0.4695 - accuracy: 0.7911 - val_loss: 0.2182 - val_accuracy: 0.9194
#
# Epoch 00007: val_accuracy improved from 0.91129 to 0.91935, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n5.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 8/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6008 - accuracy: 0.7380The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 729ms/step - loss: 0.6008 - accuracy: 0.7380 - val_loss: 0.2023 - val_accuracy: 0.9476
#
# Epoch 00008: val_accuracy improved from 0.91935 to 0.94758, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n5.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 9/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3950 - accuracy: 0.8271The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 686ms/step - loss: 0.3950 - accuracy: 0.8271 - val_loss: 0.3065 - val_accuracy: 0.8387
#
# Epoch 00009: val_accuracy did not improve from 0.94758
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 10/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6325 - accuracy: 0.7449The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 687ms/step - loss: 0.6325 - accuracy: 0.7449 - val_loss: 0.2021 - val_accuracy: 0.9113
#
# Epoch 00010: val_accuracy did not improve from 0.94758
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 11/60
# 73/73 [==============================] - ETA: 0s - loss: 0.4906 - accuracy: 0.7740The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 727ms/step - loss: 0.4906 - accuracy: 0.7740 - val_loss: 0.2985 - val_accuracy: 0.8831
#
# Epoch 00011: val_accuracy did not improve from 0.94758
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 12/60
# 73/73 [==============================] - ETA: 0s - loss: 0.4528 - accuracy: 0.8048The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 687ms/step - loss: 0.4528 - accuracy: 0.8048 - val_loss: 0.2143 - val_accuracy: 0.9194
#
# Epoch 00012: val_accuracy did not improve from 0.94758
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 36/60
# 73/73 [==============================] - ETA: 0s - loss: 0.2668 - accuracy: 0.9007The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 693ms/step - loss: 0.2668 - accuracy: 0.9007 - val_loss: 0.1270 - val_accuracy: 0.9597
#
# Epoch 00036: val_accuracy improved from 0.95161 to 0.95968, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n5.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 37/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3442 - accuracy: 0.8647The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 691ms/step - loss: 0.3442 - accuracy: 0.8647 - val_loss: 0.2080 - val_accuracy: 0.9476
#
# Epoch 00037: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 38/60
# 73/73 [==============================] - ETA: 0s - loss: 0.2779 - accuracy: 0.8887The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 732ms/step - loss: 0.2779 - accuracy: 0.8887 - val_loss: 0.1530 - val_accuracy: 0.9476
#
# Epoch 00038: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 39/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3255 - accuracy: 0.8699The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 733ms/step - loss: 0.3255 - accuracy: 0.8699 - val_loss: 0.1479 - val_accuracy: 0.9516
#
# Epoch 00039: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 40/60
# 73/73 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.8801The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 691ms/step - loss: 0.2844 - accuracy: 0.8801 - val_loss: 0.1666 - val_accuracy: 0.9516
#
# Epoch 00040: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 41/60
# 73/73 [==============================] - ETA: 0s - loss: 0.2613 - accuracy: 0.8955The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 686ms/step - loss: 0.2613 - accuracy: 0.8955 - val_loss: 0.2677 - val_accuracy: 0.8831
#
# Epoch 00041: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 42/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3208 - accuracy: 0.8733The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 689ms/step - loss: 0.3208 - accuracy: 0.8733 - val_loss: 0.1811 - val_accuracy: 0.9435
#
# Epoch 00042: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 43/60
# 73/73 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.8887The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 729ms/step - loss: 0.2677 - accuracy: 0.8887 - val_loss: 0.3509 - val_accuracy: 0.8508
#
# Epoch 00043: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 44/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3399 - accuracy: 0.8562The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 729ms/step - loss: 0.3399 - accuracy: 0.8562 - val_loss: 0.2841 - val_accuracy: 0.8750
#
# Epoch 00044: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 45/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3186 - accuracy: 0.8716The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 730ms/step - loss: 0.3186 - accuracy: 0.8716 - val_loss: 0.2620 - val_accuracy: 0.8831
#
# Epoch 00045: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 46/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.8699The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 687ms/step - loss: 0.3586 - accuracy: 0.8699 - val_loss: 0.1562 - val_accuracy: 0.9355
#
# Epoch 00046: val_accuracy did not improve from 0.95968
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 47/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3614 - accuracy: 0.8442The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] -
shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 690ms/step - loss: 0.2811 - accuracy: 0.8818 - val_loss: 0.2675 - val_accuracy: 0.8589
#
# Epoch 00058: val_accuracy did not improve from 0.96774
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 59/60
# 73/73 [==============================] - ETA: 0s - loss: 0.2986 - accuracy: 0.8955The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 731ms/step - loss: 0.2986 - accuracy: 0.8955 - val_loss: 0.2401 - val_accuracy: 0.8911
#
# Epoch 00059: val_accuracy did not improve from 0.96774
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 60/60
# 73/73 [==============================] - ETA: 0s - loss: 0.3386 - accuracy: 0.8647The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 740ms/step - loss: 0.3386 - accuracy: 0.8647 - val_loss: 0.2896 - val_accuracy: 0.8710
#
# Epoch 00060: val_accuracy did not improve from 0.96774
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# Epoch 1/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7444 - accuracy: 0.4863The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 55s 748ms/step - loss: 0.7444 - accuracy: 0.4863 - val_loss: 0.6941 - val_accuracy: 0.5000
#
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n6.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 2/60
# 73/73 [==============================] - ETA: 0s - loss: 1.4656 - accuracy: 0.5051The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 736ms/step - loss: 1.4656 - accuracy: 0.5051 - val_loss: 0.6976 - val_accuracy: 0.5000
#
# Epoch 00002: val_accuracy did not improve from 0.50000
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 3/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7443 - accuracy: 0.4949The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 736ms/step - loss: 0.7443 - accuracy: 0.4949 - val_loss: 0.6854 - val_accuracy: 0.5000
#
# Epoch 00003: val_accuracy did not improve from 0.50000
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 4/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7235 - accuracy: 0.4914The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 736ms/step - loss: 0.7235 - accuracy: 0.4914 - val_loss: 0.7462 - val_accuracy: 0.5000
#
# Epoch 00004: val_accuracy did not improve from 0.50000
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 5/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7247 - accuracy: 0.4846The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 734ms/step - loss: 0.7247 - accuracy: 0.4846 - val_loss: 0.6699 - val_accuracy: 0.5161
#
# Epoch 00005: val_accuracy improved from 0.50000 to 0.51613, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n6.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 6/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6792 - accuracy: 0.5548The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 736ms/step - loss: 0.6792 - accuracy: 0.5548 - val_loss: 0.5972 - val_accuracy: 0.5444
#
# Epoch 00006: val_accuracy improved from 0.51613 to 0.54435, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n6.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 7/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7144 - accuracy: 0.5377The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 738ms/step - loss: 0.7144 - accuracy: 0.5377 - val_loss: 0.6535 - val_accuracy: 0.5121
#
# Epoch 00007: val_accuracy did not improve from 0.54435
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 8/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6904 - accuracy: 0.5942The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 692ms/step - loss: 0.6904 - accuracy: 0.5942 - val_loss: 0.6911 - val_accuracy: 0.5000
#
# Epoch 00008: val_accuracy did not improve from 0.54435
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 9/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7156 - accuracy: 0.5205The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 726ms/step - loss: 0.7156 - accuracy: 0.5205 - val_loss: 0.7445 - val_accuracy: 0.5000
#
# Epoch 00009: val_accuracy did not improve from 0.54435
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 10/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6733 - accuracy: 0.5514The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 685ms/step - loss: 0.6733 - accuracy: 0.5514 - val_loss: 0.6400 - val_accuracy: 0.5202
#
# Epoch 00010: val_accuracy did not improve from 0.54435
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 11/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6904 - accuracy: 0.6130The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 739ms/step - loss: 0.6904 - accuracy: 0.6130 - val_loss: 0.6949 - val_accuracy: 0.5000
#
# Epoch 00011: val_accuracy did not improve from 0.54435
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 12/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7039 - accuracy: 0.5154The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 694ms/step - loss: 0.7039 - accuracy: 0.5154 - val_loss: 0.7007 - val_accuracy: 0.5000
#
# Epoch 00012: val_accuracy did not improve from 0.54435
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 13/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7009 - accuracy: 0.5205The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 687ms/step - loss: 0.7009 - accuracy: 0.5205 - val_loss: 0.6593 - val_accuracy: 0.5323
#
# Epoch 00013: val_accuracy did not improve from 0.54435
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 14/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6898 - accuracy: 0.5394The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 688ms/step - loss: 0.6898 - accuracy: 0.5394 - val_loss: 0.6465 - val_accuracy: 0.5726
#
# Epoch 00014: val_accuracy improved from 0.54435 to 0.57258, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n6.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 15/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6634 - accuracy: 0.6027The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 736ms/step - loss: 0.6634 - accuracy: 0.6027 - val_loss: 0.6428 - val_accuracy: 0.5685
#
# Epoch 00015: val_accuracy did not improve from 0.57258
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 16/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6617 - accuracy: 0.6027The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 729ms/step - loss: 0.6617 - accuracy: 0.6027 - val_loss: 0.6074 - val_accuracy: 0.7419
#
# Epoch 00016: val_accuracy improved from 0.57258 to 0.74194, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n6.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 17/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6843 - accuracy: 0.5685The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 730ms/step - loss: 0.6843 - accuracy: 0.5685 - val_loss: 0.5806 - val_accuracy: 0.8306
#
# Epoch 00017: val_accuracy improved from 0.74194 to 0.83065, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n6.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 18/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6199 - accuracy: 0.6627The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 689ms/step - loss: 0.6199 - accuracy: 0.6627 - val_loss: 0.5168 - val_accuracy: 0.8065
#
# Epoch 00018: val_accuracy did not improve from 0.83065
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 19/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6087 - accuracy: 0.6644The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 50s 691ms/step - loss: 0.6087 - accuracy: 0.6644 - val_loss: 0.4399 - val_accuracy: 0.8024
#
# Epoch 00019: val_accuracy did not improve from 0.83065
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 20/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6529 - accuracy: 0.6798The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 724ms/step - loss: 0.6529 - accuracy: 0.6798 - val_loss: 0.4134 - val_accuracy: 0.8468
#
# Epoch 00020: val_accuracy improved from 0.83065 to 0.84677, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n6.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 21/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.6250The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 701ms/step - loss: 0.6938 - accuracy: 0.6250 - val_loss: 0.5295 - val_accuracy: 0.8145
#
# Epoch 00021: val_accuracy did not improve from 0.84677
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 22/60
# ...
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 34/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6257 - accuracy: 0.6712The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 699ms/step - loss: 0.6257 - accuracy: 0.6712 - val_loss: 0.6181 - val_accuracy: 0.7621
#
# Epoch 00034: val_accuracy improved from 0.73387 to 0.76210, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n7.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 35/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6557 - accuracy: 0.6353The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 705ms/step - loss: 0.6557 - accuracy: 0.6353 - val_loss: 0.5510 - val_accuracy: 0.7782
#
# Epoch 00035: val_accuracy improved from 0.76210 to 0.77823, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n7.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 36/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6326 - accuracy: 0.6336The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 55s 749ms/step - loss: 0.6326 - accuracy: 0.6336 - val_loss: 0.6295 - val_accuracy: 0.6613
#
# Epoch 00036: val_accuracy did not improve from 0.77823
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 37/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6655 - accuracy: 0.5976The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 724ms/step - loss: 0.6655 - accuracy: 0.5976 - val_loss: 0.5917 - val_accuracy: 0.6855
#
# Epoch 00037: val_accuracy did not improve from 0.77823
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 38/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6990 - accuracy: 0.6199The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 52s 716ms/step - loss: 0.6990 - accuracy: 0.6199 - val_loss: 0.8125 - val_accuracy: 0.5040
#
# Epoch 00038: val_accuracy did not improve from 0.77823
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 39/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6989 - accuracy: 0.5839The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 55s 753ms/step - loss: 0.6989 - accuracy: 0.5839 - val_loss: 0.7287 - val_accuracy: 0.5000
#
# Epoch 00039: val_accuracy did not improve from 0.77823
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 40/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6856 - accuracy: 0.5599The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 703ms/step - loss: 0.6856 - accuracy: 0.5599 - val_loss: 0.6545 - val_accuracy: 0.7581
#
# Epoch 00040: val_accuracy did not improve from 0.77823
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 41/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6481 - accuracy: 0.6575The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 701ms/step - loss: 0.6481 - accuracy: 0.6575 - val_loss: 0.5967 - val_accuracy: 0.8024
#
# Epoch 00041: val_accuracy improved from 0.77823 to 0.80242, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n7.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 42/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6923 - accuracy: 0.6216The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 696ms/step - loss: 0.6923 - accuracy: 0.6216 - val_loss: 0.7070 - val_accuracy: 0.5000
#
# Epoch 00042: val_accuracy did not improve from 0.80242
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 43/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.6079The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 747ms/step - loss: 0.6615 - accuracy: 0.6079 - val_loss: 0.6353 - val_accuracy: 0.5323
#
# Epoch 00043: val_accuracy did not improve from 0.80242
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 44/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6304 - accuracy: 0.6284The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 742ms/step - loss: 0.6304 - accuracy: 0.6284 - val_loss: 0.4349 - val_accuracy: 0.8306
#
# Epoch 00044: val_accuracy improved from 0.80242 to 0.83065, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n7.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 45/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6024 - accuracy: 0.6712The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 701ms/step - loss: 0.6024 - accuracy: 0.6712 - val_loss: 0.3319 - val_accuracy: 0.8669
#
# Epoch 00045: val_accuracy improved from 0.83065 to 0.86694, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n7.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 46/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6160 - accuracy: 0.6849The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 734ms/step - loss: 0.6160 - accuracy: 0.6849 - val_loss: 0.6870 - val_accuracy: 0.5887
#
# Epoch 00046: val_accuracy did not improve from 0.86694
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 47/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6283 - accuracy: 0.6507The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 734ms/step - loss: 0.6283 - accuracy: 0.6507 - val_loss: 0.4784 - val_accuracy: 0.8266
#
# Epoch 00047: val_accuracy did not improve from 0.86694
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 48/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5863 - accuracy: 0.7089The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 737ms/step - loss: 0.5863 - accuracy: 0.7089 - val_loss: 0.3242 - val_accuracy: 0.8710
#
# Epoch 00048: val_accuracy improved from 0.86694 to 0.87097, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n7.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 49/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5302 - accuracy: 0.7363The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 734ms/step - loss: 0.5302 - accuracy: 0.7363 - val_loss: 0.3837 - val_accuracy: 0.8589
#
# Epoch 00049: val_accuracy did not improve from 0.87097
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 50/60
# 73/73 [==============================] - ETA: 0s - loss: 0.4888 - accuracy: 0.7791The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 705ms/step - loss: 0.4888 - accuracy: 0.7791 - val_loss: 0.3129 - val_accuracy: 0.9274
#
# Epoch 00050: val_accuracy improved from 0.87097 to 0.92742, saving model to /content/gdrive/My Drive/overlap/New setup/9_18_n=1_10_Lrelu_weights_model_n7.hdf5
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 51/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6129 - accuracy: 0.6798The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 704ms/step - loss: 0.6129 - accuracy: 0.6798 - val_loss: 0.4385 - val_accuracy: 0.8105
#
# Epoch 00051: val_accuracy did not improve from 0.92742
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 52/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5498 - accuracy: 0.7346The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 697ms/step - loss: 0.5498 - accuracy: 0.7346 - val_loss: 0.3165 - val_accuracy: 0.8790
#
# Epoch 00052: val_accuracy did not improve from 0.92742
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 53/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5467 - accuracy: 0.7175The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 57s 775ms/step - loss: 0.5467 - accuracy: 0.7175 - val_loss: 0.5265 - val_accuracy: 0.8105
#
# Epoch 00053: val_accuracy did not improve from 0.92742
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 54/60
# 73/73 [==============================] - ETA: 0s - loss: 0.6055 - accuracy: 0.6849The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 703ms/step - loss: 0.6055 - accuracy: 0.6849 - val_loss: 0.7121 - val_accuracy: 0.5000
#
# Epoch 00054: val_accuracy did not improve from 0.92742
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 55/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5900 - accuracy: 0.6747The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 52s 708ms/step - loss: 0.5900 - accuracy: 0.6747 - val_loss: 0.4299 - val_accuracy: 0.7903
#
# Epoch 00055: val_accuracy did not improve from 0.92742
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 56/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5876 - accuracy: 0.6901The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 738ms/step - loss: 0.5876 - accuracy: 0.6901 - val_loss: 0.4644 - val_accuracy: 0.8185
#
# Epoch 00056: val_accuracy did not improve from 0.92742
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 57/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5979 - accuracy: 0.6901The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 54s 739ms/step - loss: 0.5979 - accuracy: 0.6901 - val_loss: 0.5030 - val_accuracy: 0.7379
#
# Epoch 00057: val_accuracy did not improve from 0.92742
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 58/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5365 - accuracy: 0.7123The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 696ms/step - loss: 0.5365 - accuracy: 0.7123 - val_loss: 0.4902 - val_accuracy: 0.8750
#
# Epoch 00058: val_accuracy did not improve from 0.92742
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 59/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5108 - accuracy: 0.7551The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 51s 699ms/step - loss: 0.5108 - accuracy: 0.7551 - val_loss: 0.3204 - val_accuracy: 0.8992
#
# Epoch 00059: val_accuracy did not improve from 0.92742
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 60/60
# 73/73 [==============================] - ETA: 0s - loss: 0.5134 - accuracy: 0.7397The shape after overlap:
# (248, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 53s 729ms/step - loss: 0.5134 - accuracy: 0.7397 - val_loss: 0.3734 - val_accuracy: 0.8347
#
# Epoch 00060: val_accuracy did not improve from 0.92742
# The shape after overlap:
# (584, 201, 201, 3)
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)

# %%
np.save('9_18_tacc.npy', train_accs)
np.save('9_18_vacc.npy', val_accs)
np.save('9_18_tacca.npy', train_accs_ave)
np.save('9_18_vacca.npy', val_accs_ave)

plt.figure(figsize=(10,5))
plt.xticks(overlaps)
plt.plot(overlaps, train_accs, label='train acc', marker='o')
plt.plot(overlaps, val_accs, label='val acc', marker='o')
#plt.plot(overlaps, test_accs, label='test acc', marker='o')
plt.xlabel("Number of overlaps",fontsize=16)
plt.ylabel("Accuracy",fontsize=16)
plt.grid()
plt.title("Train&Val Acc V.S. Overlap Number n")
plt.legend(prop = {'size':14})

plt.figure(figsize=(10,5))
plt.xticks(overlaps)
plt.plot(overlaps, train_accs_ave, label='train acc', marker='o')
plt.plot(overlaps, val_accs_ave, label='val acc', marker='o')
#plt.plot(overlaps, test_accs, label='test acc', marker='o')
plt.xlabel("Number of overlaps",fontsize=16)
plt.ylabel("Accuracy",fontsize=16)
plt.grid()
plt.title("Train&Val Acc V.S. Overlap Number n")
plt.legend(prop = {'size':14})

# %% [markdown]
# Select the final accuracy for both test and validation

# %%
####### if we select the final accuracy for both test and validation #######
overlaps = np.arange(1, 6, 1)
train_accs = np.zeros_like(overlaps, dtype=np.float)
train_losses = np.zeros_like(overlaps, dtype=np.float)
test_accs = np.zeros_like(overlaps, dtype=np.float)
test_losses = np.zeros_like(overlaps, dtype=np.float)
val_accs = np.zeros_like(overlaps, dtype=np.float)
val_losses = np.zeros_like(overlaps, dtype=np.float)
for i, overlap in tqdm(enumerate(overlaps), total=len(overlaps)):
    generator_train = OverlapGenerator(positive_images=positive_train_images, negative_images=negative_train_images, overlap_number=overlap,batch_size=8)
    generator_val = OverlapGenerator(positive_images=positive_val_images, negative_images=negative_val_images, overlap_number=overlap,batch_size=8,aug = False)

    model = make_cnn_model(summarize=False)
    adam = keras.optimizers.Adamax(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)
    model.compile(adam, loss='categorical_crossentropy',metrics=['accuracy']) 
    model.fit(x=generator_train, validation_data=generator_val, epochs=60, verbose=1)
    history = model.history.history
    # train_accs[i] = np.mean(history['accuracy'][20:50])
    # train_losses[i] = np.mean(history['loss'][20:50])
    # val_accs[i] = np.mean(history['val_accuracy'][20:50])
    # val_losses[i] = np.mean(history['val_loss'][20:50])

    train_accs[i] = history['accuracy'][59]
    train_losses[i] = history['loss'][59]
    val_accs[i] = history['val_accuracy'][59]
    val_losses[i] = history['val_loss'][59]
    pt = '/content/gdrive/My Drive/overlap/New setup/new_my_model_n' + str(i+1)+'.h5'
    model.save(pt) 
    # ####### model2 for validation #######
    # generator_val = OverlapGenerator(positive_images=positive_val_images, negative_images=negative_val_images, overlap_number=overlap,batch_size=8, aug = False)
    # model2 = make_cnn_model(summarize=False)
    # model2.compile(adam, loss='categorical_crossentropy',metrics=['accuracy'])
    # model2.fit(x=generator_train, validation_data=generator_val, epochs=50, verbose=1)
    # history2 = model2.history.history
    # val_accs[i] = np.mean(history2['val_accuracy'])
    # val_losses[i] = np.mean(history2['val_loss'])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# Epoch 1/60
# 73/73 [==============================] - ETA: 0s - loss: 0.7948 - accuracy: 0.6500Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 46s 616ms/step - loss: 0.7914 - accuracy: 0.6513 - val_loss: 0.2280 - val_accuracy: 0.8992
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 2/60
# 73/73 [==============================] - ETA: 0s - loss: 0.2018 - accuracy: 0.9065Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 44s 608ms/step - loss: 0.2011 - accuracy: 0.9070 - val_loss: 0.0772 - val_accuracy: 0.9718
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 3/60
# 73/73 [==============================] - ETA: 0s - loss: 0.1074 - accuracy: 0.9703Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] -
before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 46s 627ms/step - loss: 0.2679 - accuracy: 0.9043 - val_loss: 0.0930 - val_accuracy: 0.9718
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)
# Epoch 60/60
# 73/73 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9447Before reshape The shape =
# (248, 201, 201, 3)
# After reshape The shape =
# (31, 8, 201, 201, 3)
# 73/73 [==============================] - 45s 622ms/step - loss: 0.1879 - accuracy: 0.9447 - val_loss: 0.1070 - val_accuracy: 0.9597
# Before reshape The shape =
# (584, 201, 201, 3)
# After reshape The shape =
# (73, 8, 201, 201, 3)

# %%
plt.figure(figsize=(10,5))
plt.xticks(overlaps)
plt.plot(overlaps, train_accs, label='train acc', marker='o')
plt.plot(overlaps, val_accs, label='val acc', marker='o')
#plt.plot(overlaps, test_accs, label='test acc', marker='o')
plt.xlabel("Number of overlaps",fontsize=16)
plt.ylabel("Accuracy",fontsize=16)
plt.title("Train&Val Acc V.S. Overlap Number n")
plt.legend(prop = {'size':14})

# %% [markdown]
# Select the average accuracy for both test and validation

# %%
overlaps = np.arange(1, 8, 1)
train_accs = np.zeros_like(overlaps, dtype=np.float)
train_losses = np.zeros_like(overlaps, dtype=np.float)
test_accs = np.zeros_like(overlaps, dtype=np.float)
test_losses = np.zeros_like(overlaps, dtype=np.float)
val_accs = np.zeros_like(overlaps, dtype=np.float)
val_losses = np.zeros_like(overlaps, dtype=np.float)
for i, overlap in tqdm(enumerate(overlaps), total=len(overlaps)):
    generator_train = OverlapGenerator(positive_images=positive_train_images, negative_images=negative_train_images, overlap_number=overlap,batch_size=8)
    generator_val = OverlapGenerator(positive_images=positive_val_images, negative_images=negative_val_images, overlap_number=overlap,batch_size=8)#,aug = False

    model = make_cnn_model(summarize=False)
    adam = keras.optimizers.Adamax(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)
    model.compile(adam, loss='categorical_crossentropy',metrics=['accuracy']) 
    model.fit(x=generator_train, validation_data=generator_val, epochs=60, verbose=1)
    history = model.history.history
    train_accs[i] = np.mean(history['accuracy'][54:59])
    train_losses[i] = np.mean(history['loss'][54:59])
    val_accs[i] = np.mean(history['val_accuracy'][54:59])
    val_losses[i] = np.mean(history['val_loss'][54:59])

# %%
plt.figure(figsize=(10,5))
plt.xticks(overlaps)
plt.plot(overlaps, train_accs, label='train acc', marker='o')
plt.plot(overlaps, val_accs, label='val acc', marker='o')
#plt.plot(overlaps, test_accs, label='test acc', marker='o')
plt.xlabel("Number of overlaps",fontsize=16)
plt.ylabel("Accuracy",fontsize=16)
plt.title("Train&Val Acc V.S. Overlap Number n")
plt.legend(prop = {'size':14})

# %%
generator_train.overlapped_images.shape
# Out:
# (73, 8, 201, 201, 3)

# %%
plt.figure(figsize=(10,5))
plt.xticks(overlaps)
plt.plot(overlaps, train_accs, label='train acc', marker='o')
plt.plot(overlaps, val_accs, label='val acc', marker='o')
plt.plot(overlaps, test_accs, label='test acc', marker='o')
plt.xlabel("Number of overlaps",fontsize=16)
plt.ylabel("Accuracy",fontsize=16)
plt.title("Train&Test Acc V.S. Overlap Number n")
plt.legend(prop = {'size':14})

# %%
np.savetxt('3_new_mean_train_acc.csv', train_accs, delimiter = ',')
np.savetxt('3_new_mean_test_acc.csv', test_accs, delimiter = ',')
np.savetxt('3_new_mean_val_acc.csv', val_accs, delimiter = ',')

# %%
def show_in_sequence(image_sequence, rgb = False):
    #plt.figure(figsize = [8, 8])
    for indexs in range(8):
        plt.subplot(2,4,indexs+1)
        if rgb:
            plt.imshow(image_sequence[indexs,:,:,:])
        else:
            plt.imshow(image_sequence[indexs,:,:,0])
        plt.axis('off')
    plt.show()

# %%
################## use bestmodel for right&wrong classification####################
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
overlaps = np.arange(7, 8, 1)
#ww = np.zeros_like(overlaps, dtype=np.float)

test_real_label = []
test_pv = []
val_real_label = []
val_pv = []

for i, overlap in tqdm(enumerate(overlaps), total=len(overlaps)):
    generator_train = OverlapGenerator(positive_images=positive_train_images, negative_images=negative_train_images, overlap_number=overlap,batch_size=8)
    generator_test = OverlapGenerator(positive_images=positive_test_images, negative_images=negative_test_images, overlap_number=overlap,batch_size=8,aug = False)
    generator_val = OverlapGenerator(positive_images=positive_val_images, negative_images=negative_val_images, overlap_number=overlap,batch_size=8, aug = False)
   
    i = overlap - 1
    filepath=str(i+1)+"_weights.best.hdf5"

    model_for_predict = load_model("/content/gdrive/My Drive/overlap/"+filepath)

    Data = generator_train
    bnum = Data.labels.shape[0]
    #bnum = 121
    bsize = 8
    model = model_for_predict
    predict_result = np.zeros((bnum,bsize), dtype=np.int)
    predict_r2 = np.zeros((bnum,bsize), dtype=np.float)
    real_label = np.zeros((bnum,bsize), dtype=np.int)
    savepath = "/content/gdrive/My Drive/overlap/newoverlap/for_paper_figures/Figure 3/"

    number_sum_tp = 1
    number_sum_tn = 1
    number_sum_fn = 1
    number_sum_fp = 1

    for k in range(bnum):
      predict_result[k,:] = np.argmax(model.predict(Data.overlapped_images[k]), axis=1)# return 0 or 1
      predict_r2[k,:] = model.predict(Data.overlapped_images[k])[:,1]# return the probability of 1
      real_label[k,:] = np.argmax(Data.labels[k,:,:], axis=1)# since it's a heatmap,return the true label

      for j in range(bsize):
        # if number_sum > 3:
        #   break
        if (real_label[k, j] == 0) and (predict_result[k,j] == 1):
          if number_sum_fp > 3:
            break
          print("n = "+ str(i+1) + "----- Flase Positive")
          imname = "n = "+ str(i+1) + "_Flase Positive_"+str(number_sum_fp)+".png"
          plt.imsave(savepath+imname,Data.overlapped_images[k,j,:,:,0])
          number_sum_fp += 1
          print("predict_value ="+ str(predict_r2[k,j]))
          plt.figure()
          plt.gray()
          plt.title("n = "+str(i+1)+ ", pv: "+str(round(predict_r2[k,j], 2)),fontsize=15)
          plt.imshow(Data.overlapped_images[k,j,:,:,0])
          plt.show
          plt.pause(1)

        if (real_label[k, j] == 1) and (predict_result[k,j] == 1):
          if number_sum_tp > 3:
            break
          print("n = "+ str(i+1) + "----- True Positive")
          imname = "n = "+ str(i+1) + "_True Positive_"+str(number_sum_tp)+".png"
          number_sum_tp +=1
          print("predict_value ="+ str(predict_r2[k,j]))
          plt.figure()
          plt.gray()
          plt.title("n = "+str(i+1)+ ", pv: "+str(round(predict_r2[k,j], 2)),fontsize=15)
          plt.imshow(Data.overlapped_images[k,j,:,:,0])
          plt.imsave(savepath+imname,Data.overlapped_images[k,j,:,:,0])
          plt.show
          plt.pause(1)

        if (real_label[k, j] == 0) and (predict_result[k,j] == 0):
          if number_sum_tn > 3:
            break
          print("n = "+ str(i+1) + "----- True Negative")
          imname = "n = "+ str(i+1) + "_True Negative_"+str(number_sum_tn)+".png"
          plt.imsave(savepath+imname,Data.overlapped_images[k,j,:,:,0])
          number_sum_tn += 1
          print("predict_value ="+ str(predict_r2[k,j]))
          plt.figure()
          plt.gray()
          plt.title("n = "+str(i+1)+ ", pv: "+str(round(predict_r2[k,j], 2)),fontsize=15)
          plt.imshow(Data.overlapped_images[k,j,:,:,0])
          plt.show
          plt.pause(1)

        if (real_label[k, j] == 1) and (predict_result[k,j] == 0):
          if number_sum_fn > 3:
            break
          print("n = "+ str(i+1) + "----- False Negative")
          imname = "n = "+ str(i+1) + "_False Negative_"+str(number_sum_fn)+".png"
          plt.imsave(savepath+imname,Data.overlapped_images[k,j,:,:,0])
          number_sum_fn += 1
          print("predict_value ="+ str(predict_r2[k,j]))
          plt.figure()
          plt.gray()
          plt.title("n = "+str(i+1)+ ", pv: "+str(round(predict_r2[k,j], 2)),fontsize=15)
          plt.imshow(Data.overlapped_images[k,j,:,:,0])
          plt.show
          plt.pause(1)


          
    # pr = predict_result.flatten();
    # pr2 = predict_r2.flatten();
    # rl = real_label.flatten();
    
    # rl,pr, pr2=SS_test(model_for_predict, generator_test, 8,"Confusion Matrix of Test", normalize = False)
    # test_real_label.append(rl)
    # test_pv.append(pr2)
    

    # rl_,pr_, pr2_=SS_test(model_for_predict, generator_val, 8,"Confusion Matrix of Validation", normalize = False)
    # val_real_label.append(rl_)
    # val_pv.append(pr2_)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# (507, 28, 28, 1)
# (40, 28, 28, 1)
# (218, 28, 28, 1)
# n = 7----- True Negative
# predict_value =0.07643366605043411
# n = 7----- False Negative
# predict_value =0.26339682936668396
# n = 7----- True Negative
# predict_value =0.3445609211921692
# n = 7----- True Negative
# predict_value =0.04524320736527443
# n = 7----- True Positive
# predict_value =0.703931987285614
# n = 7----- Flase Positive
# predict_value =0.5634881258010864
# n = 7----- True Positive
# predict_value =0.6354990601539612
# n = 7----- Flase Positive
# predict_value =0.5827670097351074
# n = 7----- True Positive
# predict_value =0.8142668604850769
# n = 7----- False Negative
# predict_value =0.12775321304798126
# n = 7----- Flase Positive
# predict_value =0.5867657661437988
# n = 7----- False Negative
# predict_value =0.13888368010520935

# %%
for k in range(10):
  print("n = "+str(k +))
  generator_val = OverlapGenerator(positive_images=positive_val_images, negative_images=negative_val_images, overlap_number=k+1,batch_size=8, aug = False)
  plt.pause(1)
# Out:
# n = 1
# (218, 28, 28, 1)
# n = 2
# (218, 28, 28, 1)
# n = 3
# (218, 28, 28, 1)
# n = 4
# (218, 28, 28, 1)
# n = 5
# (218, 28, 28, 1)
# n = 6
# (218, 28, 28, 1)
# n = 7
# (218, 28, 28, 1)
# n = 8
# (218, 28, 28, 1)
# n = 9
# (218, 28, 28, 1)
# n = 10
# (218, 28, 28, 1)
